# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Creating list to append tweet data 
query = "piala dunia u 20 lang:id until:2023-04-06 since:2023-03-30"
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    if i>20: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.user.username, tweet.rawContent]) #declare the attributes to be returned
    
# Creating a dataframe from the tweets list above 
df = pd.DataFrame(tweets_list1, columns=['Datetime','Username', 'Text'])
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1648959705727787008-19c63677d2cf3a53'

# %%
df
# Out:
#                     Datetime         Username  \
# 0  2023-04-05 23:57:19+00:00  halintarbungkam
# 1  2023-04-05 23:54:25+00:00    kirarachelsea
# 2  2023-04-05 23:29:31+00:00   teodorikgultom
# 3  2023-04-05 23:22:27+00:00       03__nakula
# 4  2023-04-05 23:18:25+00:00     Aprilia_wiji
# 5  2023-04-05 23:15:02+00:00        RepelitaO
# 6  2023-04-05 23:14:14+00:00     Aprilia_wiji
# 7  2023-04-05 23:12:24+00:00     Aprilia_wiji
# 8  2023-04-05 23:03:25+00:00    JemberNetwork
# 9  2023-04-05 22:59:05+00:00     Aprilia_wiji
# 10 2023-04-05 22:55:46+00:00    Rizkybaswedan
# 11 2023-04-05 22:41:39+00:00            zoxar
# 12 2023-04-05 22:33:34+00:00        MarkEsso8
# 13 2023-04-05 22:31:08+00:00        hdw_tahir
# 14 2023-04-05 22:13:15+00:00         GamantoY
# 15 2023-04-05 22:13:12+00:00   putrafajar1945
# 16 2023-04-05 22:12:24+00:00      fajaronline
# 17 2023-04-05 22:09:18+00:00           MuhiqR
# 18 2023-04-05 22:08:28+00:00         Liga8583
# 19 2023-04-05 22:06:26+00:00          PBola99
# 20 2023-04-05 21:45:01+00:00     WartaEkonomi
#
#                                                  Text
# 0   @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...
# 1   Gagalnya perhelatan piala dunia U-20 di Indone...
# 2   @tatakujiyati Tapi @aniesbaswedan kan sering m...
# 3   Dicoret sebagai tuan rumah piala dunia U-20, b...
# 4   Ketua umum Erick Thohir mengungkapkan alasan F...
# 5   Bukan Cuma Soal Piala Dunia U-20, Ini Sederet ...
# 6   Dukungan penuh dan simpati diberikan oleh warg...
# 7   Meskipun FIFA telah membatalkan posisi Indones...
# 8   Ganjar Pranowo sebutkan alasan utama tolak ked...
# 9   Ketua umum PSSI Erick Thohir berharap sepak bo...
# 10  Terimakasih FIFA Krena TDK menjadikan Indonesi...
# 11  Pemerintah RI hamburkan uang triliunan untuk p...
# 12  Ketum PSSI Erick Thohir berharap FIFA tak menj...
# 13  @Miduk17 Salah satunya ganjar biang kerok bata...
# 14  Terjawab sudah bukan karena statmen Ganjar, pi...
# 15  @Paltiwest Memang sulit Anies ini, selain gak ...
# 16  Survei Terbaru: Elektabilitas Ganjar Terjun Be...
# 17  PDIP Singgung Anies Baswedan yang Diam soal Ti...
# 18  Piala Dunia U-20: Cabut Status Tuan Rumah Indo...
# 19  Piala Dunia U-20: Cabut Status Tuan Rumah Indo...
# 20  Elektabilitas Ganjar Pranowo Terbukti Kena Pen...

# %%
df.to_csv("/Users/arman/Skripsi/Dataset/BigData/RawData/Piala-Dunia-20223-FIX-noFilter.csv", index=False)
